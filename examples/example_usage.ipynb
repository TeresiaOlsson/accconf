# %%
# Create a backend database

from accconf.backends.json_db import JSONBackend

db = JSONBackend(path='doc_test.json', initialize=False)

# %%
# Connect to the database with the manager

from accconf import ConfigManager

manager = ConfigManager(path='doc_test.json')

# %%
# Create a new item

from accconf import BaseItem

item = BaseItem(name='test', class_name='test.class')

print(item.to_dict())
# Out:
# {'name': 'test', 'class_name': 'test.class', 'args': [], 'kwargs': {}}

# %%
# Add the item to the database

manager.add_item(item)
# Out:
# 'test'
